# %% [markdown]
# # Conditional Statements

# %% [markdown]
# ### It decides how a code should flow using if, else, elif etc

# %%
number = "+91-8056580356"
msg1 = "The caller is from India"
msg2 = "Not from India"

# %%
if ('+91' in number):
    print(msg1)
    msg1 = 'New msg updated'
    print(msg1)
else:
    print(msg2)
# Out:
# The caller is from India
# New msg updated

# %%
num = int(input("Enter a number: "))
if (num%2 ==0 ):
    print("The nummber is even")
if (num%2 !=0):
    print("The number is odd")
# Out:
# Enter a number: 5
# The number is odd

# %%
LoggedIn = False

if (LoggedIn):
    print("present")
else:
    print('absent')
# Out:
# absent

# %% [markdown]
# ### IF, Elif and Else

# %% [markdown]
# ### Used when we have multiple conditions

# %%
char = input("Enater a character: ")
if (char >='a' and char <='z'):
    print("It is a Small case Character")
elif (char >='A' and char <= "Z"):
    print("It is a Capital character")
elif (char >= '0' and char <= '9'):
    print("It is a Number")
else:
    print("It is special Character")
# Out:
# Enater a character: #
# It is special Character

# %% [markdown]
# ## Nested If

# %%
hungry = True
money = 400

restaurantopen = True

# %%
if (hungry):
    if(money == 0):
        print('Just Sleep')
    elif (money > 500):
        print ("Have a feast")
    elif (money >100 and money < 500):
        print("have something great")
        if (restaurantopen):
            print("Restaurant is open, order in")
        else:
            print('have food the next day')
else:
    print("we wont eat")
# Out:
# have something great
# Restaurant is open, order in

# %%
char = input("Enter a character: ")

# %%
1%32
# Out:
# 31

# %% [markdown]
# Question
#
# Implement the check loan eligibility function that deetermines a persons loan eligibility based on therir age, annual income and credit score. use nested if statements to implement the following logic
#
# the person must be under 18 years old
# - if income is 30,000 or more:
#     - Credit score 700+: Prime loan
#     - credit score 600 - 700: Standard loan
#     - crredit score below 600: High risk loan
# - if income is 20,000 - 29,999:
#     - Credit score 700+: Standard loan
#     - Credit score 600 - 699: High risk loan
#     - Credit sccore below 600: Not eligible
# - if income is below 20,000: Not eligible

# %%
age = 20
income = 35000
creditscore = 750

# %%
if (age>=18):
    if (income>=30000):
        if (creditscore >= 700):
            print("Prime loan")
        elif (creditscore >= 600 and creditscore <700):
            print("Standard loan")
        elif (creditscore<600):
            print("High risk loan")
        
    elif(income>=20000 and income<30000):
        if (creditscore >= 700):
            print("Standard loan")
        elif (creditscore >= 600 and creditscore <700):
            print("High risk loan")
        elif (creditscore<600):
            print("Not eligible")        
        
    else:
        print("not eligible")
        
    
else:
    print("not eligible")
# Out:
# Prime loan

# %% [markdown]
# question 2
#
# Write a program to check if an year is leap year or not

# %%
year = 2000

# %%
if (year %4 == 0):
    if (year %100 ==0):
        if (year %400 ==0):
            print("it is a leap year")
        else:
            print("Not a leap year")
    else:
        print("it is a leap year")
else:
    print("It is not a leap year")
# Out:
# it is a leap year
