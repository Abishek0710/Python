# %% [markdown]
# # List Operations
#
# #### List helps to store sequence of items within a single variable
#
# #### It can be accessed using index values
#
# #### List elements are mutable
#
# #### List can store elements of different types ie it is hetrogenous in nature
#
# #### It also allows duplicates

# %%
lst = [1,3,5,6,8]

# %%
lst[3] = 7

# %%
lst
# Out:
# [1, 3, 5, 7, 8]

# %%
list2 = ['Abi',3,5,6, 3.14]

# %%
list2
# Out:
# ['Abi', 3, 5, 6, 3.14]

# %%
# Another way of creating a list
# using list method we can able to create list
l3 = list((1,2,3,4,5))

# %%
l3
# Out:
# [1, 2, 3, 4, 5]

# %%
# Slicing in list
list2[0:3]
# Out:
# ['Abi', 3, 5]

# %%
# concatination in list

lst + list2
# Out:
# [1, 3, 5, 7, 8, 'Abi', 3, 5, 6, 3.14]

# %%
list2 * 3
# Out:
# ['Abi', 3, 5, 6, 3.14, 'Abi', 3, 5, 6, 3.14, 'Abi', 3, 5, 6, 3.14]

# %%
1 in l3
# Out:
# True

# %%
l4 = [[1,1,1],5, 8.9, 'Abi' ]

# %%
1  in l4
# Out:
# False

# %%
# iterating a list

for i in l4:
    print(i)
# Out:
# [1, 1, 1]
# 5
# 8.9
# Abi

# %%
len(l4)
# Out:
# 4

# %%
l4[3][2]
# Out:
# 'i'

# %% [markdown]
# ## Functions in list

# %%
# length function
len(l4)
# Out:
# 4

# %%
l5 = [56,879,9089,2855,1004]
l6 = ['abi','xcf']

# %%
max(l5), max(l6)
# Out:
# (9089, 'xcf')

# %%
l4
# Out:
# [[1, 1, 1], 5, 8.9, 'Abi']

# %%
# we cannot compare elements with different dtypes
max(l4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # we cannot compare elements with different dtypes
# ----> 2 max(l4)
#
# TypeError: '>' not supported between instances of 'int' and 'list'

# %%
# Sum function
sum(l5)
# Out:
# 13883

# %%
# sorted
sorted(l5)
# Out:
# [56, 879, 1004, 2855, 9089]

# %%
# any give true if there is anay value in the list

null_list = [0,0,[],None]
any_list = [0,0,[],None,1]

# %%
any(null_list), any(any_list)
# Out:
# (False, True)

# %% [markdown]
# ## Methods in list

# %% [markdown]
# ##### function is called on a object or a variable    eg. max(lst)
# ##### method needs an object to call    eg. lst.append()

# %%
l4
# Out:
# [[1, 1, 1], 5, 8.9, 'Abi']

# %%
#append method
l4.append(6)

# %%
l4
# Out:
# [[1, 1, 1], 5, 8.9, 'Abi', 6]

# %%
# extend method
# it is similar to conacatinating a 2 list

l4.extend(l5)

# %%
print(l4)
print(l5)
# Out:
# [[1, 1, 1], 5, 8.9, 'Abi', 6, 56, 879, 9089, 2855, 1004]
# [56, 879, 9089, 2855, 1004]

# %%
# Insert method insert(index,element)
l5.insert(0,10)

# %%
l5
# Out:
# [10, 56, 879, 9089, 2855, 1004]

# %%
# index method
# gives the index of a particular element

l5.index(10)
# Out:
# 0

# %%
# count method
# gives the no of times an element has occured

l5.append(10)
l5
# Out:
# [10, 56, 879, 9089, 2855, 1004, 10, 10]

# %%
l5.count(10)
# Out:
# 3

# %%
# remove method 
# Removes a particular element from a list which ocurs first

l5.remove(10)
l5
# Out:
# [56, 879, 9089, 2855, 1004, 10, 10]

# %%
# pop method
# removes last element
l5.pop()
l5
# Out:
# [56, 879, 9089, 2855, 1004, 10]

# %%
l7 = []

# %%
pop(l7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 pop(l7)
#
# NameError: name 'pop' is not defined

# %%
# pop wont work on empty list to handle this we use in this way
if len(l7) !=0:
    pop(l7)

# %%
# reverse method

l5.reverse()
l5
# Out:
# [10, 1004, 2855, 9089, 879, 56]

# %%
l5[::-1]
# Out:
# [56, 879, 9089, 2855, 1004, 10]

# %%
# Sort method

l5.sort()
l5
# Out:
# [10, 56, 879, 1004, 2855, 9089]

# %%
# sorting in descending
l5.sort(reverse=True)

# %%
l5
# Out:
# [9089, 2855, 1004, 879, 56, 10]

# %%
# copy method
l5copy = l5.copy()

# %%
l5copy
# Out:
# [9089, 2855, 1004, 879, 56, 10]

# %%
l5.append(1)

# %%
l5copy
# Out:
# [9089, 2855, 1004, 879, 56, 10, 1]

# %%
l5
# Out:
# [9089, 2855, 1004, 879, 56, 10, 1]
